# %%
# !pip install pinecone
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 742.8/742.8 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.7/280.7 kB 10.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import Pinecone client and serverless config

# %%
from pinecone import Pinecone, ServerlessSpec

# %% [markdown]
# # Initialize Pinecone with API Key

# %%
pc = Pinecone(api_key = 'pcsk_43iMyg_FuaYohhbQ61QL7JhvGsNGp2nnXxaqsWUaRBndMWWiJ6QQM4FzAsu29WQijnbpnQ')

# %% [markdown]
# # List all available indexes

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "ss",
#         "metric": "cosine",
#         "host": "ss-f0nks6q.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1024,
#         "deletion_protection": "disabled",
#         "tags": null,
#         "embed": {
#             "model": "llama-text-embed-v2",
#             "field_map": {
#                 "text": "test"
#             },
#             "dimension": 1024,
# ...

# %% [markdown]
# # Create a new Pinecone index

# %%
pc.create_index(name = 'test',
                dimension = 3,
                spec = ServerlessSpec(
                    cloud = 'aws',
                    region = 'us-east-1'
                ))
# Out:
# {
#     "name": "test",
#     "metric": "cosine",
#     "host": "test-f0nks6q.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 3,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
# ...

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "ss",
#         "metric": "cosine",
#         "host": "ss-f0nks6q.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1024,
#         "deletion_protection": "disabled",
#         "tags": null,
#         "embed": {
#             "model": "llama-text-embed-v2",
#             "field_map": {
#                 "text": "test"
#             },
#             "dimension": 1024,
# ...
