# %%
pip install pinecone

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
pc = Pinecone(api_key = 'pcsk_4vCge1_JNAxwK6QAHeZt2awoGpZdYp89274cY4g6vuv6JcDzt5rfMvcTHTkoHb8ZNzYDKJ')

# %% [markdown]
# #Creation of Index

# %%
pc.list_indexes()
# Out:
# IndexList([<name='sample-movies', dim=1024, ready=True>, <name='aaft', dim=3, ready=True>])

# %%
pc.create_index(name="test",
               dimension = 3,
               spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )  ) # free tier use only us-east-1
# Out:
# IndexModel(name='test', metric='cosine', host='https://test-yhwv74v.svc.aped-4627-b74a.pinecone.io', status=IndexStatus(ready=True, state='Ready'), spec=IndexSpec(serverless=ServerlessSpecInfo(cloud='aws', region='us-east-1', read_capacity={'mode': 'OnDemand', 'status': {'state': 'Ready', 'current_shards': None, 'current_replicas': None}}, source_collection=None, schema=None), pod=None, byoc=None), vector_type='dense', dimension=3, deletion_protection='disabled', tags=None, embed=None, created_at=None)

# %%
pc.list_indexes()
# Out:
# IndexList([<name='test', dim=3, ready=True>, <name='sample-movies', dim=1024, ready=True>, <name='aaft', dim=3, ready=True>])

# %%
pc.create_index(name="aaft",
               dimension = 3,
               spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )  )
# Out:
# IndexModel(name='aaft', metric='cosine', host='https://aaft-yhwv74v.svc.aped-4627-b74a.pinecone.io', status=IndexStatus(ready=True, state='Ready'), spec=IndexSpec(serverless=ServerlessSpecInfo(cloud='aws', region='us-east-1', read_capacity={'mode': 'OnDemand', 'status': {'state': 'Ready', 'current_shards': None, 'current_replicas': None}}, source_collection=None, schema=None), pod=None, byoc=None), vector_type='dense', dimension=3, deletion_protection='disabled', tags=None, embed=None, created_at=None)

# %%
pc.list_indexes()
# Out:
# IndexList([<name='sample-movies', dim=1024, ready=True>, <name='aaft', dim=3, ready=True>])

# %% [markdown]
# #UPSERT in Pinecone

# %%
# UPSERT
idx = pc.Index("aaft")

# %%
pc.list_indexes()
# Out:
# IndexList([<name='sample-movies', dim=1024, ready=True>, <name='aaft', dim=3, ready=True>])

# %%
data = [('vec1', [1.0, 2.0, 3.0]), ('vec2', [11.0, 12.0, 13.0]), ('vec3', [31.0, 32.0, 33.0])]

# %%
idx.upsert(vectors=data)
# Out:
# UpsertResponse(upserted_count=3)

# %% [markdown]
# **Updation**
#
# 1. List of Vectors to be inserted first.
# ("A", [0.1, 0.1, 0.1]),
# ("B", [0.2, 0.2, 0.2]),
# ("C", [0.3, 0.3, 0.3]),
# ("D", [0.4, 0.4, 0.4]),
# ("E", [0.5, 0.5, 0.5])
# 2. Update Vector "E" with values [0.55, 0.55, 0.55]

# %%
from pinecone import Pinecone
from tqdm.notebook import tqdm # warning taken care of


pc = Pinecone(api_key ='pcsk_4vCge1_JNAxwK6QAHeZt2awoGpZdYp89274cY4g6vuv6JcDzt5rfMvcTHTkoHb8ZNzYDKJ')

# %%
idx = pc.Index('aaft')

# %%
idx.upsert(vectors = [
    ("A", [0.1, 0.1, 0.1]),
("B", [0.2, 0.2, 0.2]),
("C", [0.3, 0.3, 0.3]),
("D", [0.4, 0.4, 0.4]),
("E", [0.5, 0.5, 0.5])
])
# Out:
# UpsertResponse(upserted_count=5)

# %%
idx.update(id="E", values=[0.55, 0.55, 0.55])
# Out:
# UpdateResponse(matched_records=None, response_info=ResponseInfo(raw_headers={'date': 'Thu, 07 May 2026 05:37:32 GMT', 'content-type': 'application/json', 'content-length': '2', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '3', 'x-pinecone-request-logical-size': '13', 'x-pinecone-request-latency-ms': '165', 'x-envoy-upstream-service-time': '165', 'x-pinecone-response-duration-ms': '167', 'grpc-status': '0', 'server': 'envoy'}))
